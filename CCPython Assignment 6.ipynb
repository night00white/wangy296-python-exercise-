# %%
# !pip install requests
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# ...

# %%
# !pip install bs4
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# ...

# %%
# The request library will grab the page
import requests

response = requests.get("https://en.wikipedia.org/wiki/Andrew_Ng")

# %%
response.text
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Andrew Ng - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"X9f5hApAICoAAJjKRuoAAABR","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Andrew_Ng","wgTitle":"Andrew Ng","wgCurRevisionId":993855035,"wgRevisionId":993855035,"wgArticleId":25277512,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Use mdy dates from April 2019","Articles with short description","Short description matches Wikidata","Articles with hCards","Articles containing Chinese-language text","Articles conta
# ...
